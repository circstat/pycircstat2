# %%
import numpy as np
import matplotlib.pyplot as plt

import pycircstat2 as cs
from pycircstat2 import load_data

# %% [markdown]
# ## Circular Data Examples

# %% [markdown]
# ### Ungrouped Data / Scatter Diagram

# %%
data_zar_ex2_ch26 = load_data('D1', source='zar_2010', print_meta=True)
# Out:
# {
#     "Description": "Compass directions of eight trees learning toward.",
#     "Examples": "26.2, 26.4, 27.1, 27.24",
#     "Columns": {
#         "θ": {
#             "name": "θ",
#             "type": "vectors",
#             "unit": "degree"
#         }
#     }
# }

# %%
data_zar_ex2_ch26
# Out:
#      θ
# 1   45
# 2   55
# 3   81
# 4   96
# 5  110
# 6  117
# 7  132
# 8  154

# %%
circ_zar_ex2_ch26 = cs.Circular(data=data_zar_ex2_ch26['θ'].values, 
                             unit='degree',
                             n_intervals=360)
circ_zar_ex2_ch26
# Out:
# Circular Data
# ...
#
# Summary
# -------
#   Grouped?: No
#   Unit: degree
#   Sample size: 8
#   Angular mean: 98.99 ( p=0.0019 ** )
#   Angular mean CI: 73.11 - 124.44
#   Angular median: 103.00
#   Angular deviation (s): 33.88
#   Circular standard deviation (s0): 35.51
#   Concentration (r): 0.83
#   Concentration (kappa): 3.21
#
# Signif. codes:
# --------------
#  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Method
# ------
#   Angular median: deviation

# %%
fig = plt.figure(figsize=(24, 12))
ax = [fig.add_subplot(121 + i, projection='polar') for i in range(2)]
circ_zar_ex2_ch26.plot(density_kwargs={'method': 'nonparametric'}, ax=ax[0])
circ_zar_ex2_ch26.plot(density_kwargs={'method': 'MoVM'}, ax=ax[1])
# Out:
# Median CI is not plotted because it is not computed.
# Median CI is not plotted because it is not computed.

# %% [markdown]
# ### Grouped Data / Rose Diagram

# %%
data_zar_ex3_ch26 = load_data('D2', source='zar_2010', print_meta=True)
# Out:
# {
#     "Description": "A sample of circular data, presented as a frequency table, where θi is an angle and fi is the observed frequency of θi.",
#     "Examples": "26.3, 26.5",
#     "Columns": {
#         "θ": {
#             "name": "center of intervals",
#             "type": "vectors",
#             "unit": "degree"
#         },
#         "θ_lower": {
#             "name": "lower bound of θ",
#             "type": "vectors",
#             "unit": "degree"
#         },
#         "θ_uppwer": {
#             "name": "upper bound of θ",
#             "type": "vectors",
#             "unit": "degree"
#         },
#         "w": {
#             "name": "frequency",
#             "type": "int"
#         },
#         "v": {
#             "name": "relative frequency",
#             "type": "float"
#         }
#     }
# }

# %%
data_zar_ex3_ch26
# Out:
#      w     v  θ_lower  θ_upper    θ
# 1    0  0.00        0       30   15
# 2    6  0.06       30       60   45
# 3    9  0.09       60       90   75
# 4   13  0.12       90      120  105
# 5   15  0.14      120      150  135
# 6   22  0.21      150      180  165
# 7   17  0.16      180      210  195
# 8   12  0.11      210      240  225
# 9    8  0.08      240      270  255
# 10   3  0.03      270      300  285
# 11   0  0.00      300      330  315
# 12   0  0.00      330      360  345

# %%
circ_zar_ex3_ch26 = cs.Circular(data=data_zar_ex3_ch26['θ'].values, 
                           w=data_zar_ex3_ch26['w'].values,
                           unit='degree',
                           n_intervals=360)
circ_zar_ex3_ch26
# Out:
# Circular Data
# ...
#
# Summary
# -------
#   Grouped?: Yes
#   Unit: degree
#   Sample size: 105
#   Angular mean: 161.57 ( p=0.0000 *** )
#   Angular mean CI: 147.59 - 175.54
#   Angular median: 162.95
#   Angular deviation (s): 53.93
#   Circular standard deviation (s0): 61.99
#   Concentration (r): 0.55
#   Concentration (kappa): 1.32
#
# Signif. codes:
# --------------
#  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Method
# ------
#   Angular median: deviation

# %%
circ_zar_ex3_ch26.plot(density_kwargs={'method': 'MoVM'})
# Out:
# Median CI is not plotted because it is not computed.

# %%
# %load_ext watermark
# %watermark --time --date --timezone --updated --python --iversions --watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2023-01-13 15:41:53CET
#
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.5.0
#
# numpy      : 1.23.5
# pycircstat2: 0.1.0
# matplotlib : 3.5.3
# sys        : 3.10.6 | packaged by conda-forge | (main, Aug 22 2022, 20:43:44) [Clang 13.0.1 ]
#
# Watermark: 2.3.1
